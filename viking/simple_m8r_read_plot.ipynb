# %% [markdown]
# # Example showing how mix python and madagascar processing #
#
# This notebook:
#     * reads in madagascar .rsf file
#     * plots using matplotlib.pyplot.imshow
#
# The notebook can be run in Python 3 (using git updates from m8r.py and doc.py on July 27, 2018)

# %%
# basic imports.  
import os
import numpy as np
import matplotlib
# use the nbagg backend to render plot.  It provides basic zoom and pan capability.
matplotlib.use('nbagg') # previously I used this magic command: %matplotlib inline
# I think import matplotlib.pyplot must be after matplotlib.use('nbagg') 
import matplotlib.pyplot as plt

#m8r library provides read and write of madagascar data
import m8r

# %%
# read the files from amazon stoage on internet
os.system('wget https://s3.amazonaws.com/open.source.geoscience/open_data/Mobil_Avo_Viking_Graben_Line_12/paracdpsubinline.rsf')
# Out:
# 0

# %%
os.system('wget https://s3.amazonaws.com/open.source.geoscience/open_data/Mobil_Avo_Viking_Graben_Line_12/parastackinline.rsf')
# Out:
# 0

# %%
#read 'file2.rsf' into numpy ndarray and plot using matplotlib.pyplot.imshow
stackfile = m8r.Input('parastackinline.rsf')
stack=stackfile.read()
plt.imshow(stack.T,aspect='auto',clim=(-5000000.,5000000.))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#read 'paracdpsubinline.rsf' into numpy ndarray and plot using matplotlib.pyplot.imshow
cdpfile = m8r.Input('paracdpsubinline.rsf')
cdps=cdpfile.read()

# %%
cdps.shape
# Out:
# (21, 60, 1500)

# %%
cdps=cdps.reshape((21*60,1500))
plt.imshow(cdps.T,aspect='auto',clim=(-5000000.,5000000.))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
